# %%
import sklearn
import seaborn as sns
import pandas as pd
import numpy as np
from copy import deepcopy
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# %%
URL_TRAIN_CSV = "https://gitlab.com/villainnumber1/filesml_proyecto_2/-/raw/main/train.csv"
URL_TEST_CSV = "https://gitlab.com/villainnumber1/filesml_proyecto_2/-/raw/main/test.csv"


X = pd.read_csv(URL_TRAIN_CSV, sep=",")
Y = pd.read_csv(URL_TEST_CSV, sep=",")

X
# Out:
#            ID  Customer_ID  Month               Name   Age          SSN  \
# 0       43161         3985      4          Lawrencez  40.0  856431180.0
# 1       40663        49494      2          Mohammedr  39.0  417453942.0
# 2      111059         2925      6          Alistairn  17.0  499528888.0
# 3       72139        21358      2       Dinesh Naire  22.0  859449371.0
# 4      119841        21221      4             Bakerg  26.0  485239890.0
# ...       ...          ...    ...                ...   ...          ...
# 79995   42636        39869      7  Hendrik Sackmannb  50.0  217529489.0
# 79996  114031        38305      2              Alexj  33.0   98861902.0
# 79997   85991         9976      6     Luciana Lopezi  25.0  745835485.0
# 79998   21240        13193      7      Edward Krudyd  15.0  894419091.0
# 79999   73558        15294      5              Neilp  30.0   17531609.0
#
#           Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 0         Accountant       97384.44            8167.370000                1.0
# 1             Writer       31369.58            2607.131667                8.0
# 2             Writer       30171.86            2772.321667                6.0
# 3             Doctor       13100.02            1246.668333                7.0
# 4             Doctor       62313.54            5120.795000                6.0
# ...              ...            ...                    ...                ...
# 79995  Media_Manager      107761.29            9047.107500                4.0
# 79996      Scientist       16218.32            1098.526667                6.0
# 79997       Engineer       29374.77            2377.897500                3.0
# 79998        Manager       43782.45            3543.537500                6.0
# 79999         Lawyer      102215.61            8482.967500                2.0
#
#        ...  Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# 0      ...        Good            405.45                 32.643281
# 1      ...         Bad           4259.91                 39.375507
# 2      ...         Bad           3406.51                 34.039021
# 3      ...    Standard            727.29                 34.747262
# 4      ...    Standard            817.64                 24.545394
# ...    ...         ...               ...                       ...
# 79995  ...    Standard             34.09                 41.899992
# 79996  ...         Bad           4466.33                 24.275710
# 79997  ...    Standard           1189.37                 38.439021
# 79998  ...         Bad           3468.25                 24.233841
# 79999  ...        Good             79.67                 27.903216
#
#       Credit_History_Age  Payment_of_Min_Amount  Total_EMI_per_month  \
# 0                  336.0                     No            77.284943
# 1                  144.0                    Yes           171.748418
# 2                  123.0                    Yes           205.403926
# 3                  129.0                    Yes            41.177132
# 4                  122.0                     NM           196.679642
# ...                  ...                    ...                  ...
# 79995              211.0                    Yes             0.000000
# 79996               98.0                     NM            64.533114
# 79997              241.0                     NM            40.264074
# 79998               85.0                    Yes           240.664739
# 79999              366.0                     No            60.567361
#
#        Amount_invested_monthly                 Payment_Behaviour  \
# 0                    53.714219   High_spent_Large_value_payments
# 1                    44.990811   High_spent_Large_value_payments
# 2                    40.781489   High_spent_Large_value_payments
# 3                    23.005463    Low_spent_Large_value_payments
# 4                    63.346750   Low_spent_Medium_value_payments
# ...                        ...                               ...
# 79995               150.220682   High_spent_Large_value_payments
# 79996                34.457893   High_spent_Small_value_payments
# 79997                22.234178  High_spent_Medium_value_payments
# 79998                42.839562    Low_spent_Large_value_payments
# 79999                60.971467   Low_spent_Medium_value_payments
#
#       Monthly_Balance  Credit_Score
# 0          847.172909      Standard
# 1          280.855383      Standard
# 2          247.322615      Standard
# 3          298.156832      Standard
# 4          152.669902      Standard
# ...               ...           ...
# 79995      984.123010      Standard
# 79996      260.523798          Poor
# 79997      403.980355      Standard
# 79998      146.741586          Poor
# 79999      355.384222          Good
#
# [80000 rows x 28 columns]

# %%
transformersX = [
  ("ID",                                              "drop",                     [0]),
  ("Customer_ID",                                     "drop",                     [1]),
  # Puede que el mes influya en el credito del cliente?
  ("Month",                                           "drop",                     [2]),
  ("Name",                                            "drop",                     [3]),
  ("Age",                                             "passthrough",              [4]),
  ("SSN",                                             "drop",                     [5]),
  ("Occupation",                                      "drop",                     [6]),
  ("Annual_Income",                                   "passthrough",              [7]),
  ("Monthly_Inhand_Salary",                           "passthrough",              [8]),
  ("Num_Bank_Accounts",                               "passthrough",              [9]),
  ("Num_Credit_Card",                                 "passthrough",              [10]),
  ("Interest_Rate",                                   "passthrough",              [11]),
  ("Num_of_Loan",                                     "passthrough",              [12]),
  ("Type_of_Loan",                                    "drop",              [13]),
  ("Delay_from_due_date",                             "drop",              [14]),
  ("Num_of_Delayed_Payments",                         "drop",              [15]),
  ("Changed_Credit_Limit",                            "drop",                     [16]),
  ("Num_Credit_Inquiries",                            "drop",              [17]),
  ("Credit_Mix",                                      "drop",                     [18]),
  ("Outstanding_Debt",                                "drop",                     [19]),
  ("Credit_Utilization_Ratio",                        "drop",                     [20]),
  ("Credit_History_Age",                              "drop",                     [21]),
  ("Payment_of_Min_Amount",                           "drop",                     [22]),
  ("Total_EMI_per_month",                             "drop",                     [23]),
  ("Amount_invested_monthly",                         "drop",                     [24]),
  ("Payment_Behaviour",                               "drop",                     [25]),
  ("Monthly_Balance",                                 "drop",                     [26]),
  ("Credit_Score",                                    "drop",                     [27]),
]

transformersY = deepcopy(transformersX)

# Normbrar el orden de columnas de 0 a n-1
transformersY.pop(27) # Eliminar precio
for i, t in enumerate(transformersY): # Renumerar los indices de las columnas
  transformersY[i][2].pop()
  transformersY[i][2].append(i)

X_T = ColumnTransformer(transformers=transformersX).fit_transform(X)
Y_T = ColumnTransformer(transformers=transformersY).fit_transform(Y)

# %%
from sklearn.metrics import f1_score

clf = RandomForestClassifier(n_estimators=100, max_depth = 10, random_state=42)

clf.fit(X_T, X["Credit_Score"])

pred = clf.predict(Y_T)

# %%
parameters = {
  
  'n_estimators': range(5,51,10),
  'max_depth': range(1,30,5),
  
}

clf = RandomForestClassifier(n_estimators=100, max_depth = 10, random_state=42)

gs = GridSearchCV(clf, parameters, verbose=1, n_jobs=-1, cv=5, scoring = "f1_micro")

gs.fit(X_T, X["Credit_Score"])

pd.DataFrame(gs.cv_results_).sort_values('rank_test_score')
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 29       6.840447      0.943701         0.462403        0.066363
# 28       5.100698      0.063340         0.420140        0.010936
# 27       3.711381      0.045046         0.346922        0.003268
# 26       2.285218      0.038575         0.285669        0.010254
# 24       6.796962      0.750485         0.473696        0.040373
# 22       3.561122      0.026551         0.338047        0.006875
# 23       4.865917      0.062389         0.390356        0.004488
# 21       2.172930      0.025095         0.274379        0.007195
# 25       0.884550      0.015014         0.217122        0.001385
# 20       0.840041      0.013698         0.222849        0.008480
# 19       5.958168      0.725004         0.392181        0.010913
# 18       4.214572      0.045550         0.347275        0.012521
# 17       3.095517      0.035850         0.300073        0.006510
# 16       2.269967      0.439148         0.257188        0.003984
# 15       0.772072      0.017234         0.221774        0.027949
# 13       3.823178      0.554301         0.339698        0.105153
# 14       4.399048      0.169800         0.333821        0.033864
# 12       2.448959      0.031698         0.258229        0.010496
# 11       1.631749      0.193121         0.333186        0.201226
# 10       0.622229      0.016735         0.201227        0.007560
# 6        1.107180      0.016437         0.226767        0.017642
# 7        1.731200      0.011317         0.226285        0.003017
# 8        2.330554      0.040013         0.248899        0.006577
# 5        0.494824      0.007407         0.217667        0.010216
# 9        2.917706      0.028912         0.266070        0.007889
# 0        0.308470      0.012346         0.201981        0.009653
# 4        1.210254      0.012283         0.236928        0.010435
# 3        0.974996      0.009559         0.216405        0.002896
# 1        0.577137      0.060311         0.283421        0.089588
# 2        1.118066      0.330260         0.285560        0.099567
#
#    param_max_depth param_n_estimators                                 params  \
# 29              26                 45  {'max_depth': 26, 'n_estimators': 45}
# 28              26                 35  {'max_depth': 26, 'n_estimators': 35}
# 27              26                 25  {'max_depth': 26, 'n_estimators': 25}
# 26              26                 15  {'max_depth': 26, 'n_estimators': 15}
# 24              21                 45  {'max_depth': 21, 'n_estimators': 45}
# 22              21                 25  {'max_depth': 21, 'n_estimators': 25}
# 23              21                 35  {'max_depth': 21, 'n_estimators': 35}
# 21              21                 15  {'max_depth': 21, 'n_estimators': 15}
# 25              26                  5   {'max_depth': 26, 'n_estimators': 5}
# 20              21                  5   {'max_depth': 21, 'n_estimators': 5}
# 19              16                 45  {'max_depth': 16, 'n_estimators': 45}
# 18              16                 35  {'max_depth': 16, 'n_estimators': 35}
# 17              16                 25  {'max_depth': 16, 'n_estimators': 25}
# 16              16                 15  {'max_depth': 16, 'n_estimators': 15}
# 15              16                  5   {'max_depth': 16, 'n_estimators': 5}
# 13              11                 35  {'max_depth': 11, 'n_estimators': 35}
# 14              11                 45  {'max_depth': 11, 'n_estimators': 45}
# 12              11                 25  {'max_depth': 11, 'n_estimators': 25}
# 11              11                 15  {'max_depth': 11, 'n_estimators': 15}
# 10              11                  5   {'max_depth': 11, 'n_estimators': 5}
# 6                6                 15   {'max_depth': 6, 'n_estimators': 15}
# 7                6                 25   {'max_depth': 6, 'n_estimators': 25}
# 8                6                 35   {'max_depth': 6, 'n_estimators': 35}
# 5                6                  5    {'max_depth': 6, 'n_estimators': 5}
# 9                6                 45   {'max_depth': 6, 'n_estimators': 45}
# 0                1                  5    {'max_depth': 1, 'n_estimators': 5}
# 4                1                 45   {'max_depth': 1, 'n_estimators': 45}
# 3                1                 35   {'max_depth': 1, 'n_estimators': 35}
# 1                1                 15   {'max_depth': 1, 'n_estimators': 15}
# 2                1                 25   {'max_depth': 1, 'n_estimators': 25}
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 29           0.806000           0.799875           0.798750
# 28           0.804937           0.800375           0.798063
# 27           0.804562           0.799188           0.797750
# 26           0.803312           0.796875           0.797813
# 24           0.798438           0.791562           0.794438
# 22           0.798562           0.787500           0.793813
# 23           0.797063           0.788125           0.793062
# 21           0.795438           0.787062           0.790813
# 25           0.796375           0.790000           0.791750
# 20           0.786687           0.775750           0.780125
# 19           0.761312           0.754062           0.763187
# 18           0.762375           0.753813           0.763000
# 17           0.761000           0.752188           0.763250
# 16           0.758250           0.748563           0.760312
# 15           0.745812           0.740750           0.743313
# 13           0.688375           0.687625           0.692000
# 14           0.689063           0.687750           0.691750
# 12           0.687937           0.688063           0.690312
# 11           0.684937           0.684625           0.686063
# 10           0.678625           0.681688           0.682063
# 6            0.645062           0.645625           0.643875
# 7            0.645687           0.645250           0.644312
# 8            0.645062           0.645062           0.643750
# 5            0.644687           0.647437           0.642687
# 9            0.646062           0.644250           0.642125
# 0            0.579000           0.576500           0.575875
# 4            0.568562           0.565500           0.563875
# 3            0.568562           0.565312           0.563813
# 1            0.547687           0.542813           0.546063
# 2            0.547687           0.542813           0.546063
#
#     split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 29           0.800125           0.798562         0.800662        0.002737
# 28           0.800375           0.799438         0.800638        0.002311
# 27           0.802063           0.797813         0.800275        0.002653
# 26           0.799438           0.795000         0.798488        0.002807
# 24           0.796937           0.794813         0.795237        0.002343
# 22           0.796625           0.792687         0.793838        0.003784
# 23           0.796188           0.792500         0.793387        0.003160
# 21           0.794125           0.791438         0.791775        0.002905
# 25           0.790937           0.788937         0.791600        0.002566
# 20           0.784000           0.781875         0.781688        0.003690
# 19           0.763312           0.756938         0.759763        0.003666
# 18           0.761563           0.755187         0.759188        0.003879
# 17           0.762188           0.752000         0.758125        0.004976
# 16           0.757812           0.751563         0.755300        0.004461
# 15           0.746062           0.742062         0.743600        0.002075
# 13           0.693375           0.688688         0.690012        0.002254
# 14           0.692875           0.686813         0.689650        0.002316
# 12           0.692688           0.686312         0.689063        0.002215
# 11           0.688813           0.685375         0.685963        0.001504
# 10           0.680500           0.679063         0.680387        0.001369
# 6            0.649062           0.641563         0.645038        0.002448
# 7            0.648937           0.640563         0.644950        0.002690
# 8            0.648375           0.639813         0.644413        0.002762
# 5            0.650875           0.636375         0.644413        0.004870
# 9            0.648250           0.639437         0.644025        0.003056
# 0            0.580562           0.578438         0.578075        0.001703
# 4            0.568250           0.566125         0.566462        0.001752
# 3            0.560438           0.566125         0.564850        0.002690
# 1            0.553250           0.545875         0.547138        0.003439
# 2            0.547750           0.545875         0.546037        0.001793
#
#     rank_test_score
# 29                1
# 28                2
# 27                3
# 26                4
# 24                5
# 22                6
# 23                7
# 21                8
# 25                9
# 20               10
# 19               11
# 18               12
# 17               13
# 16               14
# 15               15
# 13               16
# 14               17
# 12               18
# 11               19
# 10               20
# 6                21
# 7                22
# 8                23
# 5                23
# 9                25
# 0                26
# 4                27
# 3                28
# 1                29
# 2                30

# %%
solucion = pd.DataFrame(data = {
        "ID" : Y["ID"],
        "Credit_Score": pred
    })

solucion

# %%
solucion.to_csv("solucion.csv", index = False)
