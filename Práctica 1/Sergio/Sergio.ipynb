# %%
from types import ClassMethodDescriptorType
import pandas as pd
import numpy as np

# Gráficos
# ==============================================================================
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns

# Preprocesado y análisis
# ==============================================================================
import statsmodels.api as sm
from scipy import stats
from scipy.stats import pearsonr

# Configuración matplotlib
# ==============================================================================
plt.style.use('ggplot')

# Configuración warnings
# ==============================================================================
import warnings
warnings.filterwarnings('ignore')

url = ("https://filebin.net/3sw6utbuul0sh225/train.csv")
datos = pd.read_csv(url)
var = "Inches"
#datos = datos[datos["TypeName"]=="Netbook"]
datos["Weight"] = [float(val[:-2]) for val in datos["Weight"]]
display(datos)

fig, ax = plt.subplots(1, 1, figsize=(6,4))
ax.scatter(x=datos.Weight, y=datos.Price, alpha= 0.8)
ax.set_xlabel(var)
ax.set_ylabel('Price');

print("TYPENAME")
datos = pd.read_csv(url)
for typename in set (datos["TypeName"]):
  _datos = datos[datos["TypeName"] == typename]
  print(typename, ' tiene correlación Pearson: ', _datos[var].corr(_datos['Price'], method='pearson'))

#datos = pd.read_csv(url)
print("")
print("COMPAÑÍA")
for marca in set (datos["Company"]):
  _datos = datos[datos["Company"] == marca]
  print(marca, ' tiene correlación Pearson: ', _datos[var].corr(_datos['Price'], method='pearson'))


#print("")
#print("LISTA MEMORIA")

#datos["Memory"].replace("1TB", "1024GB")
#datos["Memory"].replace("1.0TB", "1024GB")
#"1TB" in datos["Memory"]

#print("")
#print("SSD: ")
#for memoria in set (datos["Memory"]):
#  _datos = datos[datos["Memory"] == memoria]
#  if "SSD" in memoria:
#    print(memoria)
#print("")
#print("HDD: ")
#for memoria in set (datos["Memory"]):
#  _datos = datos[datos["Memory"] == memoria]
#  if "HDD" in memoria:
#    print(memoria)
#print("")
#print("Flash: ")
#for memoria in set (datos["Memory"]):
#  _datos = datos[datos["Memory"] == memoria]
#  if "Flash" in memoria:
#    print(memoria)
#print("")
#print("Hybrid: ")
#for memoria in set (datos["Memory"]):
#  _datos = datos[datos["Memory"] == memoria]
#  if "Hybrid" in memoria:
#    print(memoria)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-1-5f75d5f2548d> in <module>
#      25
#      26 url = ("https://filebin.net/3sw6utbuul0sh225/train.csv")
# ---> 27 datos = pd.read_csv(url)
#      28 var = "Inches"
#      29 #datos = datos[datos["TypeName"]=="Netbook"]
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
